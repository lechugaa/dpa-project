# %% [markdown]
# # Limpieza de los datos

# %%
import pandas as pd

# %%
# aquí están los datos en local
data_path = '/Users/cbautistap/Dropbox/MCD/Cursos/primavera-2021/dpa/data/Food_Inspections.csv'

# %%
# cargamos datos, convertimos a formato datetime la columna 'Inspection Date' y queda con formato yy/mm/dd
data = pd.read_csv(data_path, parse_dates=['Inspection Date'])

# %%
data.shape
# Out:
# (215130, 17)

# %%
data.head()
# Out:
#    Inspection ID       DBA Name       AKA Name  License # Facility Type  \
# 0        2472391   PHILZ COFFEE   PHILZ COFFEE  2766979.0           NaN
# 1        2453551           BIAN           BIAN  2744753.0    Restaurant
# 2        2386633         JIN JU         JIN JU    27137.0    Restaurant
# 3        2386595  LA BIZNAGA #2  LA BIZNAGA #2  2708992.0           NaN
# 4        2386523    MC DONALD'S    MC DONALD'S  2560785.0    Restaurant
#
#               Risk              Address     City State      Zip  \
# 0  Risk 2 (Medium)     1555 N WELLS ST   CHICAGO    IL  60610.0
# 1    Risk 1 (High)   600 W CHICAGO AVE   CHICAGO    IL  60654.0
# 2    Risk 1 (High)     5203 N CLARK ST   CHICAGO    IL  60640.0
# 3    Risk 1 (High)  2949 W BELMONT AVE   CHICAGO    IL  60618.0
# 4  Risk 2 (Medium)  6336 S ASHLAND AVE   CHICAGO    IL  60636.0
#
#   Inspection Date       Inspection Type    Results Violations   Latitude  \
# 0      2021-01-07               License  Not Ready        NaN  41.910736
# 1      2020-10-20               License       Pass        NaN  41.896585
# 2      2020-08-28               Canvass   No Entry        NaN  41.976301
# 3      2020-08-27             Complaint   No Entry        NaN  41.939256
# 4      2020-08-26  Short Form Complaint       Pass        NaN  41.778361
#
#    Longitude                                  Location
# 0 -87.634551  (-87.63455069145124, 41.910736031820235)
# 1 -87.642996  (-87.64299618172501, 41.896585191199556)
# 2 -87.668276   (-87.66827593789948, 41.97630115368914)
# 3 -87.702270  (-87.70226967930802, 41.939255926667535)
# 4 -87.664337   (-87.66433686342792, 41.77836097603761)

# %%
#data['month'] = data['Inspection Date'].dt.month

# %%
# creamos función para estandarizar el nombre de las columnas.
def standarize_column_names(data, excluded_punctuation=".,-*¿?¡!#"):
    data.columns = data.columns.str.lower().str.replace(" ", "_")
    for ch in excluded_punctuation:
        data.columns = data.columns.str.replace(ch, "")

# %%
standarize_column_names(data)
# Out:
# /Users/cbautistap/.pyenv/versions/itam_dpa/lib/python3.7/site-packages/ipykernel_launcher.py:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   """

# %%
# cambiamos el nombre de la columna license
data=data.rename(columns={'license_':'license'})
data.head(2)
# Out:
#    inspection_id      dba_name      aka_name    license facility_type  \
# 0        2472391  PHILZ COFFEE  PHILZ COFFEE  2766979.0           NaN
# 1        2453551          BIAN          BIAN  2744753.0    Restaurant
#
#               risk             address     city state      zip  \
# 0  Risk 2 (Medium)    1555 N WELLS ST   CHICAGO    IL  60610.0
# 1    Risk 1 (High)  600 W CHICAGO AVE   CHICAGO    IL  60654.0
#
#   inspection_date inspection_type    results violations   latitude  longitude  \
# 0      2021-01-07         License  Not Ready        NaN  41.910736 -87.634551
# 1      2020-10-20         License       Pass        NaN  41.896585 -87.642996
#
#                                    location
# 0  (-87.63455069145124, 41.910736031820235)
# 1  (-87.64299618172501, 41.896585191199556)

# %%
data.dtypes
# Out:
# inspection_id               int64
# dba_name                   object
# aka_name                   object
# license                   float64
# facility_type              object
# risk                       object
# address                    object
# city                       object
# state                      object
# zip                       float64
# inspection_date    datetime64[ns]
# inspection_type            object
# results                    object
# violations                 object
# latitude                  float64
# longitude                 float64
# location                   object
# dtype: object

# %% [markdown]
# Queremos convertir license y zip a string. Si lo convertimos directo astype(str) queda con decimales, por lo tanto convertimos primero a formato int. Sin embargo, ambas columnas tienen NAs por lo que una solución es llenarlos con 0 y ahora sí convertir a string. QUIZÁ NO HAY PROBLEMA TENERLOS EN STRING CON EL DECIMAL XXXX.0

# %%
data.isna().sum()
# Out:
# inspection_id          0
# dba_name               0
# aka_name            2487
# license               17
# facility_type       4892
# risk                  69
# address                0
# city                 158
# state                 50
# zip                   52
# inspection_date        0
# inspection_type        1
# results                0
# violations         57447
# latitude             710
# longitude            710
# location             710
# dtype: int64

# %%
#Subset de data frame con missing values en cualquier columna
null_data = data[data.isnull().any(axis=1)]
null_data.head()
# Out:
#    inspection_id       dba_name       aka_name    license facility_type  \
# 0        2472391   PHILZ COFFEE   PHILZ COFFEE  2766979.0           NaN
# 1        2453551           BIAN           BIAN  2744753.0    Restaurant
# 2        2386633         JIN JU         JIN JU    27137.0    Restaurant
# 3        2386595  LA BIZNAGA #2  LA BIZNAGA #2  2708992.0           NaN
# 4        2386523    MC DONALD'S    MC DONALD'S  2560785.0    Restaurant
#
#               risk              address     city state      zip  \
# 0  Risk 2 (Medium)     1555 N WELLS ST   CHICAGO    IL  60610.0
# 1    Risk 1 (High)   600 W CHICAGO AVE   CHICAGO    IL  60654.0
# 2    Risk 1 (High)     5203 N CLARK ST   CHICAGO    IL  60640.0
# 3    Risk 1 (High)  2949 W BELMONT AVE   CHICAGO    IL  60618.0
# 4  Risk 2 (Medium)  6336 S ASHLAND AVE   CHICAGO    IL  60636.0
#
#   inspection_date       inspection_type    results violations   latitude  \
# 0      2021-01-07               License  Not Ready        NaN  41.910736
# 1      2020-10-20               License       Pass        NaN  41.896585
# 2      2020-08-28               Canvass   No Entry        NaN  41.976301
# 3      2020-08-27             Complaint   No Entry        NaN  41.939256
# 4      2020-08-26  Short Form Complaint       Pass        NaN  41.778361
#
#    longitude                                  location
# 0 -87.634551  (-87.63455069145124, 41.910736031820235)
# 1 -87.642996  (-87.64299618172501, 41.896585191199556)
# 2 -87.668276   (-87.66827593789948, 41.97630115368914)
# 3 -87.702270  (-87.70226967930802, 41.939255926667535)
# 4 -87.664337   (-87.66433686342792, 41.77836097603761)

# %% [markdown]
# ### Queremos entender qué tipo de observaciones son las que tienen missing values, con el objetivo de encontrar algún patrón o algo que nos permita imputar de mejor manera.
#
# Para eso, haremos subset de missing values por columna. Empezamos con las que tienen mayor NaN.
#
# Nota. La columna de aka_name no la exploraremos. Es lógico que haya mv para esta columna, además, no la utilizaremos para el modelo

# %%
#queremos ver que observaciones son las que tienen missing values en la columna 'violations'
null_violations = null_data[null_data.violations.isnull()]
null_violations.shape
# Out:
# (57447, 17)

# %%
#Missing values en la columna 'violations'
null_data[null_data.violations.isnull()].groupby('results').count()
# Out:
#                       inspection_id  dba_name  aka_name  license  \
# results
# Business Not Located             72        72        57       72
# Fail                           3183      3183      2989     3182
# No Entry                       6796      6796      6709     6796
# Not Ready                      2226      2226      2172     2226
# Out of Business               18677     18677     18098    18676
# Pass                          25925     25925     25491    25922
# Pass w/ Conditions              568       568       563      568
#
#                       facility_type   risk  address   city  state    zip  \
# results
# Business Not Located             45     64       72     70     72     70
# Fail                           2842   3162     3183   3170   3183   3178
# No Entry                       6725   6789     6796   6790   6793   6795
# Not Ready                      2123   2210     2226   2212   2222   2223
# Out of Business               14638  18673    18677  18658  18674  18663
# Pass                          25729  25914    25925  25895  25913  25916
# Pass w/ Conditions              562    568      568    568    567    568
#
#                       inspection_date  inspection_type  violations  latitude  \
# results
# Business Not Located               72               72           0        69
# Fail                             3183             3183           0      3168
# No Entry                         6796             6796           0      6794
# Not Ready                        2226             2226           0      2218
# Out of Business                 18677            18677           0     18641
# Pass                            25925            25924           0     25799
# Pass w/ Conditions                568              568           0       567
#
#                       longitude  location
# results
# Business Not Located         69        69
# Fail                       3168      3168
# No Entry                   6794      6794
# Not Ready                  2218      2218
# Out of Business           18641     18641
# Pass                      25799     25799
# Pass w/ Conditions          567       567

# %% [markdown]
# Agrupando por Results, el 89.4% de los NaN de la columna 'Violations' están en 'Pass', 'Out of Business' y 'No Entry'. Tiene sentido que los que pasaron la inspección no tengan violaciones, asimismo, que los que ya estén cerrados y en los cuales no se entró, no tengan violaciones.
#
# Por otro lado, solo el 5% de los mv de la columna 'Violations' son de resultados 'Fail' (que representan 1.47% del total de observaciones).
# Dentro de éstas, el 62% son de Tipo de Inspección 'License'

# %%
results_fail = null_violations['results']=='Fail'

# %%
null_violations[results_fail].groupby('inspection_type').count()
# Out:
#                                           inspection_id  dba_name  aka_name  \
# inspection_type
# Business Not Located                                  1         1         1
# Canvass                                             462       462       453
# Canvass Re-Inspection                                16        16        16
# Complaint                                           128       128       118
# Complaint Re-Inspection                               6         6         6
# Complaint-Fire                                       22        22        22
# Consultation                                         45        45        42
# Duplicated                                            1         1         1
# Illegal Operation                                     1         1         0
# LICENSE REQUEST                                       4         4         4
# LICENSE WRONG ADDRESS                                 1         1         0
# LICENSE/NOT READY                                     2         2         2
# LIQOUR TASK FORCE NOT READY                           1         1         1
# License                                            1999      1999      1850
# License Re-Inspection                                65        65        57
# License-Task Force                                  100       100        98
# NO ENTRY                                              6         6         6
# NO ENTRY-SHORT COMPLAINT)                             1         1         1
# No Entry                                             28        28        28
# Non-Inspection                                        5         5         5
# Not Ready                                             6         6         6
# OUT OF BUSINESS                                       8         8         7
# OWNER SUSPENDED OPERATION/LICENSE                     1         1         0
# Out of Business                                     112       112       110
# Package Liquor 1474                                   7         7         7
# Pre-License Consultation                             11        11         9
# RECALL INSPECTION                                     1         1         1
# Recent Inspection                                     5         5         5
# Short Form Complaint                                 57        57        55
# Short Form Fire-Complaint                            17        17        17
# Special Events (Festivals)                            2         2         2
# Suspected Food Poisoning                              3         3         3
# TASK FORCE LIQUOR 1470                                1         1         1
# TASK FORCE NOT READY                                  1         1         1
# Tag Removal                                           3         3         3
# Task Force Liquor 1475                               47        47        44
# Task Force for liquor 1474                            1         1         1
# finish complaint inspection from 5-18-10              1         1         1
# no entry                                              4         4         4
# out ofbusiness                                        1         1         1
#
#                                           license  facility_type  risk  \
# inspection_type
# Business Not Located                            1              1     1
# Canvass                                       462            340   462
# Canvass Re-Inspection                          16             16    16
# Complaint                                     128            117   125
# Complaint Re-Inspection                         6              6     6
# Complaint-Fire                                 22             20    22
# Consultation                                   45             41    43
# Duplicated                                      1              1     1
# Illegal Operation                               1              1     0
# LICENSE REQUEST                                 4              1     4
# LICENSE WRONG ADDRESS                           1              1     1
# LICENSE/NOT READY                               2              2     2
# LIQOUR TASK FORCE NOT READY                     1              1     1
# License                                      1999           1898  1987
# License Re-Inspection                          65             63    65
# License-Task Force                            100             95   100
# NO ENTRY                                        6              6     6
# NO ENTRY-SHORT COMPLAINT)                       1              1     1
# No Entry                                       28             23    28
# Non-Inspection                                  5              5     5
# Not Ready                                       6              6     6
# OUT OF BUSINESS                                 8              4     8
# OWNER SUSPENDED OPERATION/LICENSE               1              0     1
# Out of Business                               112             37   112
# Package Liquor 1474                             7              7     7
# Pre-License Consultation                       11              9     8
# RECALL INSPECTION                               1              1     1
# Recent Inspection                               5              5     5
# Short Form Complaint                           56             55    57
# Short Form Fire-Complaint                      17             17    17
# Special Events (Festivals)                      2              2     2
# Suspected Food Poisoning                        3              3     3
# TASK FORCE LIQUOR 1470                          1              1     1
# TASK FORCE NOT READY                            1              1     1
# Tag Removal                                     3              3     3
# Task Force Liquor 1475                         47             45    47
# Task Force for liquor 1474                      1              1     1
# finish complaint inspection from 5-18-10        1              1     1
# no entry                                        4              4     4
# out ofbusiness                                  1              1     1
#
#                                           address  city  state   zip  \
# inspection_type
# Business Not Located                            1     1      1     1
# Canvass                                       462   462    462   462
# Canvass Re-Inspection                          16    16     16    16
# Complaint                                     128   127    128   128
# Complaint Re-Inspection                         6     6      6     6
# Complaint-Fire                                 22    22     22    22
# Consultation                                   45    45     45    45
# Duplicated                                      1     1      1     1
# Illegal Operation                               1     1      1     1
# LICENSE REQUEST                                 4     4      4     4
# LICENSE WRONG ADDRESS                           1     1      1     1
# LICENSE/NOT READY                               2     2      2     2
# LIQOUR TASK FORCE NOT READY                     1     1      1     1
# License                                      1999  1990   1999  1995
# License Re-Inspection                          65    62     65    64
# License-Task Force                            100   100    100   100
# NO ENTRY                                        6     6      6     6
# NO ENTRY-SHORT COMPLAINT)                       1     1      1     1
# No Entry                                       28    28     28    28
# Non-Inspection                                  5     5      5     5
# Not Ready                                       6     6      6     6
# OUT OF BUSINESS                                 8     8      8     8
# OWNER SUSPENDED OPERATION/LICENSE               1     1      1     1
# Out of Business                               112   112    112   112
# Package Liquor 1474                             7     7      7     7
# Pre-License Consultation                       11    11     11    11
# RECALL INSPECTION                               1     1      1     1
# Recent Inspection                               5     5      5     5
# Short Form Complaint                           57    57     57    57
# Short Form Fire-Complaint                      17    17     17    17
# Special Events (Festivals)                      2     2      2     2
# Suspected Food Poisoning                        3     3      3     3
# TASK FORCE LIQUOR 1470                          1     1      1     1
# TASK FORCE NOT READY                            1     1      1     1
# Tag Removal                                     3     3      3     3
# Task Force Liquor 1475                         47    47     47    47
# Task Force for liquor 1474                      1     1      1     1
# finish complaint inspection from 5-18-10        1     1      1     1
# no entry                                        4     4      4     4
# out ofbusiness                                  1     1      1     1
#
#                                           inspection_date  results  \
# inspection_type
# Business Not Located                                    1        1
# Canvass                                               462      462
# Canvass Re-Inspection                                  16       16
# Complaint                                             128      128
# Complaint Re-Inspection                                 6        6
# Complaint-Fire                                         22       22
# Consultation                                           45       45
# Duplicated                                              1        1
# Illegal Operation                                       1        1
# LICENSE REQUEST                                         4        4
# LICENSE WRONG ADDRESS                                   1        1
# LICENSE/NOT READY                                       2        2
# LIQOUR TASK FORCE NOT READY                             1        1
# License                                              1999     1999
# License Re-Inspection                                  65       65
# License-Task Force                                    100      100
# NO ENTRY                                                6        6
# NO ENTRY-SHORT COMPLAINT)                               1        1
# No Entry                                               28       28
# Non-Inspection                                          5        5
# Not Ready                                               6        6
# OUT OF BUSINESS                                         8        8
# OWNER SUSPENDED OPERATION/LICENSE                       1        1
# Out of Business                                       112      112
# Package Liquor 1474                                     7        7
# Pre-License Consultation                               11       11
# RECALL INSPECTION                                       1        1
# Recent Inspection                                       5        5
# Short Form Complaint                                   57       57
# Short Form Fire-Complaint                              17       17
# Special Events (Festivals)                              2        2
# Suspected Food Poisoning                                3        3
# TASK FORCE LIQUOR 1470                                  1        1
# TASK FORCE NOT READY                                    1        1
# Tag Removal                                             3        3
# Task Force Liquor 1475                                 47       47
# Task Force for liquor 1474                              1        1
# finish complaint inspection from 5-18-10                1        1
# no entry                                                4        4
# out ofbusiness                                          1        1
#
#                                           violations  latitude  longitude  \
# inspection_type
# Business Not Located                               0         1          1
# Canvass                                            0       461        461
# Canvass Re-Inspection                              0        15         15
# Complaint                                          0       128        128
# Complaint Re-Inspection                            0         6          6
# Complaint-Fire                                     0        22         22
# Consultation                                       0        45         45
# Duplicated                                         0         1          1
# Illegal Operation                                  0         1          1
# LICENSE REQUEST                                    0         4          4
# LICENSE WRONG ADDRESS                              0         1          1
# LICENSE/NOT READY                                  0         2          2
# LIQOUR TASK FORCE NOT READY                        0         1          1
# License                                            0      1986       1986
# License Re-Inspection                              0        65         65
# License-Task Force                                 0       100        100
# NO ENTRY                                           0         6          6
# NO ENTRY-SHORT COMPLAINT)                          0         1          1
# No Entry                                           0        28         28
# Non-Inspection                                     0         5          5
# Not Ready                                          0         6          6
# OUT OF BUSINESS                                    0         8          8
# OWNER SUSPENDED OPERATION/LICENSE                  0         1          1
# Out of Business                                    0       112        112
# Package Liquor 1474                                0         7          7
# Pre-License Consultation                           0        11         11
# RECALL INSPECTION                                  0         1          1
# Recent Inspection                                  0         5          5
# Short Form Complaint                               0        57         57
# Short Form Fire-Complaint                          0        17         17
# Special Events (Festivals)                         0         2          2
# Suspected Food Poisoning                           0         3          3
# TASK FORCE LIQUOR 1470                             0         1          1
# TASK FORCE NOT READY                               0         1          1
# Tag Removal                                        0         3          3
# Task Force Liquor 1475                             0        47         47
# Task Force for liquor 1474                         0         1          1
# finish complaint inspection from 5-18-10           0         1          1
# no entry                                           0         4          4
# out ofbusiness                                     0         1          1
#
#                                           location
# inspection_type
# Business Not Located                             1
# Canvass                                        461
# Canvass Re-Inspection                           15
# Complaint                                      128
# Complaint Re-Inspection                          6
# Complaint-Fire                                  22
# Consultation                                    45
# Duplicated                                       1
# Illegal Operation                                1
# LICENSE REQUEST                                  4
# LICENSE WRONG ADDRESS                            1
# LICENSE/NOT READY                                2
# LIQOUR TASK FORCE NOT READY                      1
# License                                       1986
# License Re-Inspection                           65
# License-Task Force                             100
# NO ENTRY                                         6
# NO ENTRY-SHORT COMPLAINT)                        1
# No Entry                                        28
# Non-Inspection                                   5
# Not Ready                                        6
# OUT OF BUSINESS                                  8
# OWNER SUSPENDED OPERATION/LICENSE                1
# Out of Business                                112
# Package Liquor 1474                              7
# Pre-License Consultation                        11
# RECALL INSPECTION                                1
# Recent Inspection                                5
# Short Form Complaint                            57
# Short Form Fire-Complaint                       17
# Special Events (Festivals)                       2
# Suspected Food Poisoning                         3
# TASK FORCE LIQUOR 1470                           1
# TASK FORCE NOT READY                             1
# Tag Removal                                      3
# Task Force Liquor 1475                          47
# Task Force for liquor 1474                       1
# finish complaint inspection from 5-18-10         1
# no entry                                         4
# out ofbusiness                                   1

# %%
# MV de columna 'Facility Type'
null_data[null_data.facility_type.isnull()].groupby('results').count()
# Out:
#                       inspection_id  dba_name  aka_name  license  \
# results
# Business Not Located             27        27        15       27
# Fail                            368       368       310      368
# No Entry                         71        71        54       71
# Not Ready                       103       103        72      103
# Out of Business                4040      4040      3996     4040
# Pass                            245       245       235      245
# Pass w/ Conditions               38        38        37       38
#
#                       facility_type  risk  address  city  state   zip  \
# results
# Business Not Located              0    19       27    25     27    25
# Fail                              0   354      368   367    368   367
# No Entry                          0    64       71    71     71    71
# Not Ready                         0    87      103   100    103   103
# Out of Business                   0  4036     4040  4039   4040  4040
# Pass                              0   240      245   243    245   245
# Pass w/ Conditions                0    38       38    38     38    38
#
#                       inspection_date  inspection_type  violations  latitude  \
# results
# Business Not Located               27               27           0        24
# Fail                              368              368          27       367
# No Entry                           71               71           0        71
# Not Ready                         103              103           0       103
# Out of Business                  4040             4040           1      4034
# Pass                              245              245          49       243
# Pass w/ Conditions                 38               38          32        36
#
#                       longitude  location
# results
# Business Not Located         24        24
# Fail                        367       367
# No Entry                     71        71
# Not Ready                   103       103
# Out of Business            4034      4034
# Pass                        243       243
# Pass w/ Conditions           36        36

# %% [markdown]
# El 84% de los NaN en la columna de Facility Type corresponden a results 'Out of business', 'Business Not Located' y 'No Entry'

# %%
# MV de columna 'location'
null_data[null_data.location.isnull()].groupby('results').count()
# Out:
#                       inspection_id  dba_name  aka_name  license  \
# results
# Business Not Located              3         3         1        3
# Fail                            145       145       143      145
# No Entry                          3         3         3        3
# Not Ready                         8         8         8        8
# Out of Business                  36        36        35       36
# Pass                            432       432       426      432
# Pass w/ Conditions               83        83        82       83
#
#                       facility_type  risk  address  city  state  zip  \
# results
# Business Not Located              0     1        3     3      3    3
# Fail                            144   145      145   145    145  145
# No Entry                          3     3        3     3      3    3
# Not Ready                         8     8        8     7      8    7
# Out of Business                  30    36       36    35     36   35
# Pass                            430   432      432   431    432  431
# Pass w/ Conditions               81    83       83    83     83   83
#
#                       inspection_date  inspection_type  violations  latitude  \
# results
# Business Not Located                3                3           0         0
# Fail                              145              145         130         0
# No Entry                            3                3           1         0
# Not Ready                           8                8           0         0
# Out of Business                    36               36           0         0
# Pass                              432              432         306         0
# Pass w/ Conditions                 83               83          82         0
#
#                       longitude  location
# results
# Business Not Located          0         0
# Fail                          0         0
# No Entry                      0         0
# Not Ready                     0         0
# Out of Business               0         0
# Pass                          0         0
# Pass w/ Conditions            0         0

# %% [markdown]
# En total son 710 observaciones con mv en ubicación (que coinciden con coordenadas geográficas). La mayoría son de establecimientos que pasaron la visita. Asimismo, destaca que por facility type, la mayoría son de tipo school y también incluye algunos establecimientos móviles.

# %%
# MV de columna 'location', agrupando con columna 'facility_type'
null_data[null_data.location.isnull()].groupby('facility_type').count()
# Out:
#                                   inspection_id  dba_name  aka_name  license  \
# facility_type
# BREWERY                                       4         4         4        4
# CHURCH/SPECIAL EVENT                          3         3         0        3
# Daycare Combo 1586                            1         1         0        1
# Food Vending Machines                         1         1         1        1
# GAS STATION                                   1         1         1        1
# Golden Diner                                  9         9         9        9
# Grocery Store                                25        25        25       25
# HIGH SCHOOL KITCHEN                           3         3         3        3
# Hospital                                     10        10        10       10
# Long Term Care                                7         7         7        7
# MFD TRUCK                                     5         5         5        5
# Mobile Food Dispenser                        75        75        70       75
# Mobile Food Preparer                         43        43        43       43
# Mobile Frozen Desserts Vendor                 9         9         9        9
# Mobile Prepared Food Vendor                   5         5         5        5
# PUSHCART                                      2         2         2        2
# Restaurant                                  136       136       136      136
# STORE                                         1         1         0        1
# School                                      320       320       320      320
# Shared Kitchen User (Long Term)              30        30        30       30
# Shared Kitchen User (Short Term)              4         4         4        4
# Special Event                                 2         2         2        2
#
#                                   risk  address  city  state  zip  \
# facility_type
# BREWERY                              4        4     4      4    4
# CHURCH/SPECIAL EVENT                 3        3     3      3    3
# Daycare Combo 1586                   1        1     1      1    1
# Food Vending Machines                1        1     1      1    1
# GAS STATION                          1        1     1      1    1
# Golden Diner                         9        9     8      9    8
# Grocery Store                       25       25    25     25   25
# HIGH SCHOOL KITCHEN                  3        3     3      3    3
# Hospital                            10       10    10     10   10
# Long Term Care                       7        7     7      7    7
# MFD TRUCK                            5        5     5      5    5
# Mobile Food Dispenser               75       75    75     75   75
# Mobile Food Preparer                43       43    43     43   43
# Mobile Frozen Desserts Vendor        9        9     9      9    9
# Mobile Prepared Food Vendor          5        5     5      5    5
# PUSHCART                             2        2     2      2    2
# Restaurant                         136      136   134    136  134
# STORE                                1        1     1      1    1
# School                             320      320   320    320  320
# Shared Kitchen User (Long Term)     30       30    30     30   30
# Shared Kitchen User (Short Term)     4        4     4      4    4
# Special Event                        2        2     2      2    2
#
#                                   inspection_date  inspection_type  results  \
# facility_type
# BREWERY                                         4                4        4
# CHURCH/SPECIAL EVENT                            3                3        3
# Daycare Combo 1586                              1                1        1
# Food Vending Machines                           1                1        1
# GAS STATION                                     1                1        1
# Golden Diner                                    9                9        9
# Grocery Store                                  25               25       25
# HIGH SCHOOL KITCHEN                             3                3        3
# Hospital                                       10               10       10
# Long Term Care                                  7                7        7
# MFD TRUCK                                       5                5        5
# Mobile Food Dispenser                          75               75       75
# Mobile Food Preparer                           43               43       43
# Mobile Frozen Desserts Vendor                   9                9        9
# Mobile Prepared Food Vendor                     5                5        5
# PUSHCART                                        2                2        2
# Restaurant                                    136              136      136
# STORE                                           1                1        1
# School                                        320              320      320
# Shared Kitchen User (Long Term)                30               30       30
# Shared Kitchen User (Short Term)                4                4        4
# Special Event                                   2                2        2
#
#                                   violations  latitude  longitude  location
# facility_type
# BREWERY                                    4         0          0         0
# CHURCH/SPECIAL EVENT                       3         0          0         0
# Daycare Combo 1586                         0         0          0         0
# Food Vending Machines                      0         0          0         0
# GAS STATION                                0         0          0         0
# Golden Diner                               3         0          0         0
# Grocery Store                             16         0          0         0
# HIGH SCHOOL KITCHEN                        2         0          0         0
# Hospital                                   6         0          0         0
# Long Term Care                             6         0          0         0
# MFD TRUCK                                  3         0          0         0
# Mobile Food Dispenser                     30         0          0         0
# Mobile Food Preparer                      26         0          0         0
# Mobile Frozen Desserts Vendor              3         0          0         0
# Mobile Prepared Food Vendor                5         0          0         0
# PUSHCART                                   2         0          0         0
# Restaurant                               102         0          0         0
# STORE                                      1         0          0         0
# School                                   293         0          0         0
# Shared Kitchen User (Long Term)            9         0          0         0
# Shared Kitchen User (Short Term)           1         0          0         0
# Special Event                              2         0          0         0

# %%
# MV de columna 'risk', agrupando por 'results'
null_data[null_data.risk.isnull()].groupby('results').count()
# Out:
#                       inspection_id  dba_name  aka_name  license  \
# results
# Business Not Located              8         8         2        8
# Fail                             22        22        15       22
# No Entry                          7         7         2        7
# Not Ready                        16        16         9       16
# Out of Business                   4         4         3        4
# Pass                             12        12         8       12
#
#                       facility_type  risk  address  city  state  zip  \
# results
# Business Not Located              0     0        8     8      8    8
# Fail                              8     0       22    22     22   22
# No Entry                          0     0        7     7      7    7
# Not Ready                         0     0       16    14     16   16
# Out of Business                   0     0        4     4      4    4
# Pass                              7     0       12    11     12   12
#
#                       inspection_date  inspection_type  violations  latitude  \
# results
# Business Not Located                8                8           0         6
# Fail                               22               22           1        22
# No Entry                            7                7           0         7
# Not Ready                          16               16           0        16
# Out of Business                     4                4           0         4
# Pass                               12               12           1        12
#
#                       longitude  location
# results
# Business Not Located          6         6
# Fail                         22        22
# No Entry                      7         7
# Not Ready                    16        16
# Out of Business               4         4
# Pass                         12        12

# %%
# MV de columna 'risk', agrupando por 'inspection_type'
null_data[null_data.risk.isnull()].groupby('inspection_type').count()
# Out:
#                             inspection_id  dba_name  aka_name  license  \
# inspection_type
# Canvass                                 3         3         2        3
# Complaint                              10        10         4       10
# Complaint-Fire                          1         1         0        1
# Consultation                            5         5         4        5
# Illegal Operation                       1         1         0        1
# License                                36        36        20       36
# Non-Inspection                          1         1         1        1
# Out of Business                         1         1         1        1
# Pre-License Consultation                3         3         2        3
# Short Form Complaint                    7         7         4        7
# Special Events (Festivals)              1         1         1        1
#
#                             facility_type  risk  address  city  state  zip  \
# inspection_type
# Canvass                                 0     0        3     3      3    3
# Complaint                               3     0       10    10     10   10
# Complaint-Fire                          0     0        1     1      1    1
# Consultation                            4     0        5     5      5    5
# Illegal Operation                       1     0        1     1      1    1
# License                                 2     0       36    34     36   36
# Non-Inspection                          0     0        1     1      1    1
# Out of Business                         0     0        1     1      1    1
# Pre-License Consultation                2     0        3     3      3    3
# Short Form Complaint                    3     0        7     6      7    7
# Special Events (Festivals)              0     0        1     1      1    1
#
#                             inspection_date  results  violations  latitude  \
# inspection_type
# Canvass                                   3        3           0         3
# Complaint                                10       10           1         9
# Complaint-Fire                            1        1           0         1
# Consultation                              5        5           1         5
# Illegal Operation                         1        1           0         1
# License                                  36       36           0        35
# Non-Inspection                            1        1           0         1
# Out of Business                           1        1           0         1
# Pre-License Consultation                  3        3           0         3
# Short Form Complaint                      7        7           0         7
# Special Events (Festivals)                1        1           0         1
#
#                             longitude  location
# inspection_type
# Canvass                             3         3
# Complaint                           9         9
# Complaint-Fire                      1         1
# Consultation                        5         5
# Illegal Operation                   1         1
# License                            35        35
# Non-Inspection                      1         1
# Out of Business                     1         1
# Pre-License Consultation            3         3
# Short Form Complaint                7         7
# Special Events (Festivals)          1         1

# %% [markdown]
# ## Por lo pronto, para proseguir con limpieza de datos, se decide reemplazar los MV con 0 para variables numéricas y con el valor 'na' para variables de texto.
#
# ### En primer lugar, convertimos a variables string las de license y zip

# %%
# Reemplazamos con 0 los mv en estas dos columnas
data['license']=data['license'].fillna(0)
data['zip']=data['zip'].fillna(0)

# %%
data.isna().sum()
# Out:
# inspection_id          0
# dba_name               0
# aka_name            2487
# license                0
# facility_type       4892
# risk                  69
# address                0
# city                 158
# state                 50
# zip                    0
# inspection_date        0
# inspection_type        1
# results                0
# violations         57447
# latitude             710
# longitude            710
# location             710
# dtype: int64

# %%
# convertimos columnas 'license' y 'zip'. Primero a int y luego a str
data = data.astype({"license": 'int', "zip": 'int'})
data = data.astype({"license": 'str', "zip": 'str'})
data.dtypes
# Out:
# inspection_id               int64
# dba_name                   object
# aka_name                   object
# license                    object
# facility_type              object
# risk                       object
# address                    object
# city                       object
# state                      object
# zip                        object
# inspection_date    datetime64[ns]
# inspection_type            object
# results                    object
# violations                 object
# latitude                  float64
# longitude                 float64
# location                   object
# dtype: object

# %%
data.head(2)
# Out:
#    inspection_id      dba_name      aka_name  license facility_type  \
# 0        2472391  PHILZ COFFEE  PHILZ COFFEE  2766979           NaN
# 1        2453551          BIAN          BIAN  2744753    Restaurant
#
#               risk             address     city state    zip inspection_date  \
# 0  Risk 2 (Medium)    1555 N WELLS ST   CHICAGO    IL  60610      2021-01-07
# 1    Risk 1 (High)  600 W CHICAGO AVE   CHICAGO    IL  60654      2020-10-20
#
#   inspection_type    results violations   latitude  longitude  \
# 0         License  Not Ready        NaN  41.910736 -87.634551
# 1         License       Pass        NaN  41.896585 -87.642996
#
#                                    location
# 0  (-87.63455069145124, 41.910736031820235)
# 1  (-87.64299618172501, 41.896585191199556)

# %%
# Hacemos subset de las columnas que utilizaremos para el modelo
data = data[['inspection_id', 'facility_type', 'risk', 'zip', 'inspection_date','inspection_type', 'results', 'violations', 'latitude', 'longitude']]
data.head()
# Out:
#    inspection_id facility_type             risk    zip inspection_date  \
# 0        2472391           NaN  Risk 2 (Medium)  60610      2021-01-07
# 1        2453551    Restaurant    Risk 1 (High)  60654      2020-10-20
# 2        2386633    Restaurant    Risk 1 (High)  60640      2020-08-28
# 3        2386595           NaN    Risk 1 (High)  60618      2020-08-27
# 4        2386523    Restaurant  Risk 2 (Medium)  60636      2020-08-26
#
#         inspection_type    results violations   latitude  longitude
# 0               License  Not Ready        NaN  41.910736 -87.634551
# 1               License       Pass        NaN  41.896585 -87.642996
# 2               Canvass   No Entry        NaN  41.976301 -87.668276
# 3             Complaint   No Entry        NaN  41.939256 -87.702270
# 4  Short Form Complaint       Pass        NaN  41.778361 -87.664337

# %%
data.isnull().sum()
# Out:
# inspection_id          0
# facility_type       4892
# risk                  69
# zip                    0
# inspection_date        0
# inspection_type        1
# results                0
# violations         57447
# latitude             710
# longitude            710
# dtype: int64

# %%
data[['facility_type', 'risk', 'inspection_type','violations']]=data[['facility_type', 'risk', 'inspection_type','violations']].fillna('na')

# %%
data.isnull().sum()
# Out:
# inspection_id        0
# facility_type        0
# risk                 0
# zip                  0
# inspection_date      0
# inspection_type      0
# results              0
# violations           0
# latitude           710
# longitude          710
# dtype: int64

# %%
# Cambiamos valor de results a 'Pass' y 'Not Pass' para cualquier otro
data['results'].mask(data['results'] != 'Pass', other = 'Not Pass', inplace=True)

# %%
data.groupby('results').count()
# Out:
#           inspection_id  facility_type    risk     zip  inspection_date  \
# results
# Not Pass         102489         102489  102489  102489           102489
# Pass             112641         112641  112641  112641           112641
#
#           inspection_type  violations  latitude  longitude
# results
# Not Pass           102489      102489    102211     102211
# Pass               112641      112641    112209     112209

# %% [markdown]
# Ahora, estandarizamos los valores de las columnas (quitamos acentos y eliminamos caracteres especiales)

# %%
def standarize_column_strings(data, columns, excluded_punctuation=".,-*'¿?¡!()", gap_punct="\/", special_chr="|"):
    for col in columns:
        data[col] = data[col].apply(lambda x: x.lower().replace(" ", "_"))
        data[col] = data[col].apply(lambda x: x.lower().replace("á", "a"))
        data[col] = data[col].apply(lambda x: x.lower().replace("é", "e"))
        data[col] = data[col].apply(lambda x: x.lower().replace("í", "i"))
        data[col] = data[col].apply(lambda x: x.lower().replace("ó", "o"))
        data[col] = data[col].apply(lambda x: x.lower().replace("ú", "u"))
        data[col] = data[col].apply(lambda x: x.lower().replace("ü", "u"))
        for ch in excluded_punctuation:
            data[col] = data[col].apply(lambda x: x.replace(ch, ""))
        for ch in gap_punct:
            data[col] = data[col].apply(lambda x: x.replace(ch,"_"))
        for ch in special_chr:
            data['violations'] = data['violations'].apply(lambda x: x.replace(ch,"~"))

# %%
#Convertimos variables de texto a formato estándar
col_text = data.select_dtypes(include=['object']).columns.to_list()
standarize_column_strings(data, col_text)
data.head()
# Out:
#    inspection_id facility_type           risk    zip inspection_date  \
# 0        2472391            na  risk_2_medium  60610      2021-01-07
# 1        2453551    restaurant    risk_1_high  60654      2020-10-20
# 2        2386633    restaurant    risk_1_high  60640      2020-08-28
# 3        2386595            na    risk_1_high  60618      2020-08-27
# 4        2386523    restaurant  risk_2_medium  60636      2020-08-26
#
#         inspection_type   results violations   latitude  longitude
# 0               license  not_pass         na  41.910736 -87.634551
# 1               license      pass         na  41.896585 -87.642996
# 2               canvass  not_pass         na  41.976301 -87.668276
# 3             complaint  not_pass         na  41.939256 -87.702270
# 4  short_form_complaint      pass         na  41.778361 -87.664337

# %%
# Función para reemplazar el valor de una columna específica
def replace_column_value(data, column, search_string, replace_string):
    data[column] = data[column].apply(lambda x: x.replace(search_string, replace_string))

# %%
replace_column_value(data,'facility_type', 'restuarant', 'restaurant')
replace_column_value(data,'facility_type', 'theatre', 'theater')
replace_column_value(data,'facility_type', 'herabal', 'herbal')
replace_column_value(data,'facility_type', 'day_care', 'daycare')
replace_column_value(data,'facility_type', 'long_term', 'longterm')


#'theatre', 'theater')) %>% 
#  mutate_at(vars(facility_type), ~str_replace_all(., 'herabal', 'herbal')) %>% 
#  mutate_at(vars(facility_type), ~str_replace_all(., 'day care', 'daycare')) %>% 
#  mutate_at(vars(facility_type), ~str_replace_all(., 'long term', 'longterm'))

# %%
data.loc[data['facility_type'].str.contains('childern|children|1023|5_years_old', case=False, na=None), 'facility_type'] = 'childrens_service_facility'
data.loc[data['facility_type'].str.contains('conv|mart|gas_station_store', case=False, na=None), 'facility_type'] = 'convenience_store'
data.loc[data['facility_type'].str.contains('assis|longterm|nursing|supportive', case=False, na=None), 'facility_type'] = 'assisted_living'
data.loc[data['facility_type'].str.contains('herbal_life|herbalife|herbalcal', case=False, na=None), 'facility_type'] = 'herbalife'
data.loc[data['facility_type'].str.contains('after_school', case=False, na=None), 'facility_type'] = 'after_school'
data.loc[data['facility_type'].str.contains('tavern|pub|brew|wine_tasting|bar_grill|hooka', case=False, na=None), 'facility_type'] = 'bar'
data.loc[data['facility_type'].str.contains('bakery', case=False, na=None), 'facility_type'] = 'bakery'
data.loc[data['facility_type'].str.contains('mobil|truck|mfd', case=False, na=None), 'facility_type'] = 'mobile_food'
data.loc[data['facility_type'].str.contains('kitchen', case=False, na=None), 'facility_type'] = 'kitchen'
data.loc[data['facility_type'].str.contains('restaurant|rstaurant|diner', case=False, na=None), 'facility_type'] = 'restaurant'
data.loc[data['facility_type'].str.contains('retail', case=False, na=None), 'facility_type'] = 'retail'
data.loc[data['facility_type'].str.contains('roof', case=False, na=None), 'facility_type'] = 'rooftop'
data.loc[data['facility_type'].str.contains('grocery', case=False, na=None), 'facility_type'] = 'grocery_store'
data.loc[data['facility_type'].str.contains('liquor', case=False, na=None), 'facility_type'] = 'liquor'
data.loc[data['facility_type'].str.contains('popup', case=False, na=None), 'facility_type'] = 'popup_establishment'
data.loc[data['facility_type'].str.contains('school|college|shcool', case=False, na=None), 'facility_type'] = 'school'
data.loc[data['facility_type'].str.contains('daycare', case=False, na=None), 'facility_type'] = 'daycare'
data.loc[data['facility_type'].str.contains('cafeteria|coffee|cafe', case=False, na=None), 'facility_type'] = 'coffee'
data.loc[data['facility_type'].str.contains('drug_store|pharmacy', case=False, na=None), 'facility_type'] = 'drug_store'
data.loc[data['facility_type'].str.contains('gym|fitness|weight_loss|exercise', case=False, na=None), 'facility_type'] = 'gym'
data.loc[data['facility_type'].str.contains('commissary|machine|commiasary', case=False, na=None), 'facility_type'] = 'vending_machine'
data.loc[data['facility_type'].str.contains('ice_cream|paleteria|gelato', case=False, na=None), 'facility_type'] = 'ice_cream'
data.loc[data['facility_type'].str.contains('banquet', case=False, na=None), 'facility_type'] = 'banquet'
data.loc[data['facility_type'].str.contains('lounge', case=False, na=None), 'facility_type'] = 'lounge'
data.loc[data['facility_type'].str.contains('church|religious', case=False, na=None), 'facility_type'] = 'church'
data.loc[data['facility_type'].str.contains('kiosk', case=False, na=None), 'facility_type'] = 'kiosk'
data.loc[data['facility_type'].str.contains('health|rehab', case=False, na=None), 'facility_type'] = 'health'
data.loc[data['facility_type'].str.contains('event', case=False, na=None), 'facility_type'] = 'events'
data.loc[data['facility_type'].str.contains('donut|hotdog|hot_dog|popcorn|juice|tea|dessert|deli|salad|snack|candy|shake|watermelon|smoothie|food|sushi', case=False, na=None), 'facility_type'] = 'other_food'
data.loc[data['facility_type'].str.contains('poultry|butcher|slaughter|meat', case=False, na=None), 'facility_type'] = 'butcher'
data.loc[data['facility_type'].str.contains('profit', case=False, na=None), 'facility_type'] = 'non_profit'
data.loc[data['facility_type'].str.contains('na', case=False, na=None), 'facility_type'] = 'not_specified'

# %% [markdown]
# Se reducen a 121 diferentes categorías, probablemente se puedan agrupar más

# %%
data.nunique()
# Out:
# inspection_id      215130
# facility_type         121
# risk                    5
# zip                   113
# inspection_date      2797
# inspection_type        98
# results                 2
# violations         156570
# latitude            17248
# longitude           17248
# dtype: int64

# %%
data['facility_type'].unique()
# Out:
# array(['not_specified', 'restaurant', 'general_store',
#        'childrens_service_facility', 'grocery_store', 'gas_station',
#        'bakery', 'assisted_living', 'other_food', 'school', 'catering',
#        'daycare', 'ice_cream', 'liquor', 'popup_establishment', 'gym',
#        'bar', 'hospital', 'kitchen', 'coffee', 'events', 'movie_theater',
#        'butcher', 'wholesale', 'distribution_center', 'smokehouse',
#        'other', 'banquet', 'push_carts', 'church', 'retail', 'store',
#        'theater', 'shelter', 'kiosk', 'unused_storage',
#        'chicago_park_district', 'pool', 'rooftop', 'night_club',
#        'convenience_store', 'pantry', 'summer_feeding', 'hotel', 'health',
#        'art_center', 'private_club', 'non_profit', 'vending_machine',
#        'greenhouse', 'herbalife', 'dining_hall', 'drug_store',
#        'repackaging_plant', 'service_gas_station', 'blockbuster_video',
#        'charter', 'herbal_drinks', 'hostel', 'hair_salon', 'lounge',
#        'dollar_tree', 'stadium', 'youth_housing', 'french_market_space',
#        'regulated_business', 'tobacco_store', 'dollar_store', 'riverwalk',
#        'herbal_medicine', 'beverage_silverware_warehouse', 'laundromat',
#        'clothing_store', 'shuffleboard_club_with_bar', 'furniture_store',
#        'warehouse', 'chinese_herbs', 'fish_market',
#        'summer_feeding_prep_area', 'gift_shop', 'northerly_island',
#        'pre_packaged', 'social_club', 'golf_course_conncession_stand',
#        'art_gallery', 'spa', 'museum_gallery', 'urban_farm',
#        'distributor', 'service_bar_theater', 'massage_bar', 'herbal',
#        'cell_phone_store', 'adult_family_care_center', 'pushcart',
#        'herbal_remedy', 'golf_course', 'vfw_hall', 'wine_store',
#        'video_store', 'art_gallery_w_wine_and_beer', 'day_spa',
#        'newsstand', 'music_venue', 'catering_and_wholesale',
#        'theater_bar', 'book_store', 'illegal_vendor', 'car_wash',
#        'room_service', 'herbal_store', 'boys_and_girls_club',
#        'drug_treatment_facility', 'unlicensed_facility',
#        'nutrition_store', 'peddler', 'produce_stand', 'farmers_market',
#        'linited_business', 'produce_vendor', 'incubator'], dtype=object)

# %%
# Ahora hacemos limpieza similar para columna de 'inspection_type'
data.loc[data['inspection_type'].str.contains('license', case=False, na=None), 'inspection_type'] = 'license'
data.loc[data['inspection_type'].str.contains('task_force|taskforce', case=False, na=None), 'inspection_type'] = 'task_force'
data.loc[data['inspection_type'].str.contains('canvass|canvas', case=False, na=None), 'inspection_type'] = 'canvas'
data.loc[data['inspection_type'].str.contains('complaint', case=False, na=None), 'inspection_type'] = 'complaint'
data.loc[data['inspection_type'].str.contains('food|sick', case=False, na=None), 'inspection_type'] = 'suspected_food_poisoning'
data.loc[data['inspection_type'].str.contains('out_of', case=False, na=None), 'inspection_type'] = 'out_of_business'

# %% [markdown]
# Se reducen a 45 categorías

# %%
data.nunique()
# Out:
# inspection_id      215130
# facility_type         121
# risk                    5
# zip                   113
# inspection_date      2797
# inspection_type        44
# results                 2
# violations         156570
# latitude            17248
# longitude           17248
# dtype: int64

# %%
data['inspection_type'].unique()
# Out:
# array(['license', 'canvas', 'complaint', 'recent_inspection',
#        'suspected_food_poisoning', 'consultation', 'not_ready',
#        'out_of_business', 'task_force', 'tag_removal',
#        'package_liquor_1474', 'no_entry', 'citation_reissued',
#        'special_events_festivals', 'possible_fbi', 'noninspection',
#        'office_assignment', 'fire', 'na', 'kitchen_closed_for_renovation',
#        'ob', 'corrective_action', 'illegal_operation', 'addendum',
#        'fire_complain', 'sample_collection', 'sfp', 'changed_court_date',
#        'sfp_recently_inspected', 'tavern_1470', 'expansion', 'citf',
#        'kids_cafe', 'error_save', 'taste_of_chicago',
#        'haccp_questionaire', 'summer_feeding', 'liquor_catering',
#        'reinspection', 'reinspection_of_48_hour_notice', 'duplicated',
#        'recall_inspection', 'business_not_located',
#        'reinspection_of_closeup'], dtype=object)

# %% [markdown]
# Ahora con columna 'violations'

# %%
data['violations'].unique()
# Out:
# array(['na',
#        '3_management_food_employee_and_conditional_employee;_knowledge_responsibilities_and_reporting__comments:_observed_no_written_employee_health_policy_on_site_instructed_facility_to_establish_an_appropriate_employee_health_policy_and_maintain_with_verifiable_signed_copies_on_site_for_all_food_employees__priority_foundation_violation_#738010_no_citation_issued_~_10_adequate_handwashing_sinks_properly_supplied_and_accessible__comments:_observed_no_hand_washing_signs_at_the_hand_sinks_on_premise_instructed_to_provide_~_36_thermometers_provided_&_accurate__comments:_observed_no_thermometer_on_site_to_monitor_the_internal_food_temperature_of_tcs_facility_must_obtain_and_maintain_proper_thermometers__priority_foundation_violation_#738005no_citation_issued_~_38_insects_rodents_&_animals_not_present__comments:_observed_pest_activity_with_approx_50_mice_droppings_noted_during_inspection_pest_activity_was_noted_in_the_dry_storage_room_under_the_shelves_along_the_wall_bases_and_in_the_closet_near_the_rear_exit_door_instructed_to_consult_pest_control_as_additional_services_are_needed_to_eliminate_activity_prior_to_reinspection__priority_foundation_violation_#738020a_no_citation_issued_~_41_wiping_cloths:_properly_used_&_stored__comments:_observed_wet_wiping_cloth_laying_on_prep_tables_must_properly_store_wiping_cloths_in_a_sanitizing_solution_between_use_~_47_food_&_nonfood_contact_surfaces_cleanable_properly_designed_constructed_&_used__comments:_observed_torn_door_gasket_inside_of_the_2_door_prep_cooler_and_a_broken_handle_on_the_left_instructed_to_replace_and_repairr_~_49_nonfood_food_contact_surfaces_clean__comments:_observed_grease_buildup_on_cooking_equipment_walls_surrounding_floors_and_shelving_units_in_the_kitchen_prep_areas_instructed_to_degrease_clean_and_sanitize_~_49_nonfood_food_contact_surfaces_clean__comments:_observed_an_excessive_amount_of__ice_buildup_inside_the_chest_freezer_located_in_the_break_room_must_remove_excess_ice_detail_clean_and_maintain_~_51_plumbing_installed;_proper_backflow_devices__comments:_observed_a_leak_at_the_faucet_of_the_three_compartment_sink_on_the_left_side_in_the_rear_instructed_to_repair_~_53_toilet_facilities:_properly_constructed_supplied_&_cleaned__comments:_observed_no_covered_receptacle_in_the_employee_restroom_instructed_to_provide_~_55_physical_facilities_installed_maintained_&_clean__comments:_observed_grease_buildup_food_debris_and_dirt_on_floor_under_cooking_equipment_along_walls_and_in_all_corners_in_prep_dish_washing_storage_and_basement_areas_instructed_manager_to_clean_floors_under_all_equipment_along_walls_and_in_all_corners_in_all_areas_observed_dust_buildup_on_fan_in_reachin_cooler_light_shields_in_cooking_area_and_ceiling_and_wall_vents_in_prep_and_storage_areas_instructed_manager_to_clean_and_maintain_all_fans_light_shields_and_ceiling_wall_vents_~_55_physical_facilities_installed_maintained_&_clean__comments:_observed_missing_and_damaged_floor_tiles_throughout_the_facility_instructed_to_repair_to_create_a_smooth_and_easily_cleanable_surface_must_maintain_at_all_timesobserved_missing_ceilings_tile_panels_in_the_bathroom_and_water_stained_ceiling_tiles_at_the_display_area_instructed_to_repair_replace_missing_panels_and_or_replace_the_stained_ceiling_tiles_~_55_physical_facilities_installed_maintained_&_clean__comments:_observed_dirty_and_dusty_ceiling_fans_in_the_throughout_the_facility_instructed_to_clean_and_maintain_~_55_physical_facilities_installed_maintained_&_clean__comments:_observed_clutter_in_the_break_room_instructed_to_organize_and_clean_the_break_room_~_56_adequate_ventilation_&_lighting;_designated_areas_used__comments:_observed_missing_light_bulbs_in_the_dry_storage_room_and_hallway_leading_to_the_dry_storage_room_instructed_to_provide_~_56_adequate_ventilation_&_lighting;_designated_areas_used__comments:_observed_a_missing_light_shield_in_the_dry_storage_room_and_hallway_leading_to_the_dry_storage_room_instructed_to_provide_and_maintain_at_all_times',
#        '1_person_in_charge_present_demonstrates_knowledge_and_performs_duties__comments:_observed_no_person_in_charge_during_inspection_instructed_manager_to_designate_person_in_charge_during_all_hours_of_operation_priority_foundation_~_2_city_of_chicago_food_service_sanitation_certificate__comments:_observed_no_certified_manager_on_site_when_tcs_food_prepared_and_served_a_certified_manager_must_be_on_site_and_certificate_posted_at_all_times_tcs_food_prepared_and_served_priority_foundation_738012_~_3_management_food_employee_and_conditional_employee;_knowledge_responsibilities_and_reporting__comments:__observed_no_employee_health_policy_on_site_instructed_to_provide_an_employee_health_policy_that_includes_a_signed_acknowledgement_from_each_employee_priority_foundation_738010__~_5_procedures_for_responding_to_vomiting_and_diarrheal_events__comments:__observed_no_written_procedure_nor_adequate_supplies_disposable_face_mask_disposable_mop_head_disposable_latex_gloves_or_adequate_sanitizer_must_eliminate_norovirus_on_site_to_properly_respond_to_any_vomit_or_diarrhea_events_that_can_potentially_occur_inside_of_the_food_establishment_instructed_to_provide_priority_foundation_738005_~_23_proper_date_marking_and_disposition__comments:_observed_refrigerated_ready_to_eat_tcs_food_not_dated_in_coolers_all_refrigerated_ready_toe_eat_tcs_food_held_more_than_24_hours_shall_be_clearly_marked_with_date_by_which_food_is_to_be_sold_consumed_or_discarded_priority_foundation_738005_~_36_thermometers_provided_&_accurate__comments:_observed_no_thermometers_in_coolers_instructed_manager_to_provide_thermometers_in_all_coolers_and_maintain_~_36_thermometers_provided_&_accurate__comments:_observed_no_metal_stem_thermometer_for_internal_temperatures_instructed_manager_to_provide_priority_foundation_738005_~_37_food_properly_labeled;_original_container__comments:_observed_bulk_containers_not_labeled_instructed_manager_to_label_all_bulk_containers_with_common_name_of_food_~_38_insects_rodents_&_animals_not_present__comments:_observed_over_50_mice_droppings_on_floor_along_walls_and_corners_in_furnace_room_instructed_manager_to_call_an_exterminator_for_service_clean_and_sanitiae_all_areas_priority_foundation_738020a_~_38_insects_rodents_&_animals_not_present__comments:_observed_no_pest_control_log_book_available_instructed_manager_to_provide_and_maintain_priority_foundation_738020c_~_39_contamination_prevented_during_food_preparation_storage_&_display__comments:_observed_food_items_stored_on_floor_instructed_to_elevate_all_stock_six_inches_off_floor_and_maintain_~_41_wiping_cloths:_properly_used_&_stored__comments:_observed_soiled_wiping_cloths_stored_on_prep_tables_instructed_to_store_wiping_cloths_in_sanitizing_solution_between_uses_~_47_food_&_nonfood_contact_surfaces_cleanable_properly_designed_constructed_&_used__comments:_observed_a_broken_top_on_the_reach_in_freezer_instructed_to_repair_or_replace_~_48_warewashing_facilities:_installed_maintained_&_used;_test_strips__comments:_observed_no_chemical_test_kit_available_instructed_manager_to_provide_test_kit_for_proper_sanitizer_concentration_in_sanitizing_solutions_priority_foundation_738005_~_49_nonfood_food_contact_surfaces_clean__comments:_observed_accumulated_grease_builup_food_debris_and_spills_on_fryers_coolers_freezers_prep_tables_instructed_manager_to_clean_and_maintain_~_51_plumbing_installed;_proper_backflow_devices__comments:_observed_duct_tape_and_leak_on_faucet_of_3compartment_sink_observed_front_hand_washing_sink_and_3compartment_sink_slowly_draining_instructed_manager_to_repair_and_maintain_~_53_toilet_facilities:_properly_constructed_supplied_&_cleaned__comments:_observed_no_covered_waste_recepacle_in_washroom_instructed_manager_to_provide_~_55_physical_facilities_installed_maintained_&_clean__comments:_observed_spills_on_walls_and_floors_in_need_of_cleaning_in_prep_storage_and_furnace_room_areas_instructed_manager_to_clean_and_maintain_~_55_physical_facilities_installed_maintained_&_cle ...
#        ...,
#        '16_food_protected_during_storage_preparation_display_service_and_transportation__comments:_all_food_should_be_properly_protected_from_contamination_during_storage_preparation_display_service_and_transportation__still_observed_black_substance_inside_ice_reservior_and_on_water_and_ice_contact_surfaces_machine_remains_held_tagged_for_inspection_from_10610_#154221_~_36_lighting:_required_minimum_footcandles_of_light_provided_fixtures_shielded__comments:_shielding_to_protect_against_broken_glass_falling_into_food_shall_be_provided_for_all_artificial_lighting_sources_in_preparation_service_and_display_facilities__must_provide_adequate_lighting_and_shielded_in_walk_in_cooler',
#        '29_previous_minor_violations_corrected_742090__comments:_previous_minor_violations_not_corrected_92909_report_#163447:__30_foods_inside_coolers_not_labeled_or_dated_instructed_to_label_and_date_all_foods_not_in_original_container__32_cutting_boards_not_manitained_instructed_to_replace_all_worn_boards_in_prep_area__33_coolers_sinks_deep_fryer_cabinets_prep_counter_prep_table_and_all_equipment_thruout_not_cleaned_instructed_to_detail_clean_and_sanitize__35_ceiling_thruout_not_maintained_instructed_to_replace_all_worn_ceiling_tile_and_seal_all_holes_and_repaint__35_rear_overhead_door_worn_on_sides_instructed_to_repair_door__41_unnecessary_articles_stored_inside_garage_instructed_to_remove_all_unused_articles_and_elevate_supplies_6_inches_or_higher__serious_citation_issued742090_~_34_floors:_constructed_per_code_cleaned_good_repair_coving_installed_dustless_cleaning_methods_used__comments:_floor_along_wallbase_and_between_equipment_not_cleaned_instructed_to_detail_clean_including_storage_rooms_~_40_refrigeration_and_metal_stem_thermometers_provided_and_conspicuous__comments:_thermometer_not_provided_inside_several_coolers_instructed_to_provide_all_missing_thermometers',
#        '33_food_and_nonfood_contact_equipment_utensils_clean_free_of_abrasive_detergents__comments:_all_food_and_nonfood_contact_surfaces_of_equipment_and_all_food_storage_utensils_shall_be_thoroughly_cleaned_and_sanitized_daily__interior_of_ice_machine_need_cleaning_~_34_floors:_constructed_per_code_cleaned_good_repair_coving_installed_dustless_cleaning_methods_used__comments:_the_floors_shall_be_constructed_per_code_be_smooth_and_easily_cleaned_and_be_kept_clean_and_in_good_repair__floors_need_cleaning_in_soda_dispenser_room_and_under_cooking_equipment_in_prep_area_spills_~_41_premises_maintained_free_of_litter_unnecessary_articles_cleaning__equipment_properly_stored__comments:_cleaning_equipment_shall_be_properly_stored_away_from_food_utensils_equipment_and_clean_linens___store_mopheads_upright_to_prevent_pest_breeding'],
#       dtype=object)

# %% [markdown]
# Por último, queremos contar el número de violaciones

# %%
data['num_violations'] = data['violations'].apply(lambda x: x.count('_~_') + 1 if x != 'na' else 0)

# %%
data.groupby('num_violations').count()
# Out:
#                 inspection_id  facility_type   risk    zip  inspection_date  \
# num_violations
# 0                       57447          57447  57447  57447            57447
# 1                       19218          19218  19218  19218            19218
# 2                       25281          25281  25281  25281            25281
# 3                       26601          26601  26601  26601            26601
# 4                       23306          23306  23306  23306            23306
# 5                       18568          18568  18568  18568            18568
# 6                       13724          13724  13724  13724            13724
# 7                        9504           9504   9504   9504             9504
# 8                        6744           6744   6744   6744             6744
# 9                        4629           4629   4629   4629             4629
# 10                       3080           3080   3080   3080             3080
# 11                       2143           2143   2143   2143             2143
# 12                       1486           1486   1486   1486             1486
# 13                        975            975    975    975              975
# 14                        708            708    708    708              708
# 15                        513            513    513    513              513
# 16                        313            313    313    313              313
# 17                        245            245    245    245              245
# 18                        215            215    215    215              215
# 19                        124            124    124    124              124
# 20                        102            102    102    102              102
# 21                         67             67     67     67               67
# 22                         42             42     42     42               42
# 23                         38             38     38     38               38
# 24                         19             19     19     19               19
# 25                         11             11     11     11               11
# 26                         10             10     10     10               10
# 27                          6              6      6      6                6
# 28                          4              4      4      4                4
# 29                          3              3      3      3                3
# 30                          2              2      2      2                2
# 33                          1              1      1      1                1
# 34                          1              1      1      1                1
#
#                 inspection_type  results  violations  latitude  longitude
# num_violations
# 0                         57447    57447       57447     57256      57256
# 1                         19218    19218       19218     19126      19126
# 2                         25281    25281       25281     25156      25156
# 3                         26601    26601       26601     26509      26509
# 4                         23306    23306       23306     23237      23237
# 5                         18568    18568       18568     18512      18512
# 6                         13724    13724       13724     13699      13699
# 7                          9504     9504        9504      9485       9485
# 8                          6744     6744        6744      6725       6725
# 9                          4629     4629        4629      4618       4618
# 10                         3080     3080        3080      3078       3078
# 11                         2143     2143        2143      2137       2137
# 12                         1486     1486        1486      1486       1486
# 13                          975      975         975       973        973
# 14                          708      708         708       708        708
# 15                          513      513         513       512        512
# 16                          313      313         313       313        313
# 17                          245      245         245       245        245
# 18                          215      215         215       215        215
# 19                          124      124         124       124        124
# 20                          102      102         102       102        102
# 21                           67       67          67        67         67
# 22                           42       42          42        42         42
# 23                           38       38          38        38         38
# 24                           19       19          19        19         19
# 25                           11       11          11        11         11
# 26                           10       10          10        10         10
# 27                            6        6           6         6          6
# 28                            4        4           4         4          4
# 29                            3        3           3         3          3
# 30                            2        2           2         2          2
# 33                            1        1           1         1          1
# 34                            1        1           1         1          1

# %%
data.dtypes
# Out:
# inspection_id               int64
# facility_type              object
# risk                       object
# zip                        object
# inspection_date    datetime64[ns]
# inspection_type            object
# results                    object
# violations                 object
# latitude                  float64
# longitude                 float64
# num_violations              int64
# dtype: object

# %%
data.to_csv('/Users/cbautistap/Dropbox/MCD/Cursos/primavera-2021/dpa/data/food_inspections_clean.csv', index=False)

# %%
#data.head(10000).to_csv('/Users/cbautistap/Dropbox/MCD/Cursos/primavera-2021/dpa/data/sample_cbp.csv')
